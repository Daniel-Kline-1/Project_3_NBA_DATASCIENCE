# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/danielkline/Desktop/datascience/Projects/project3'

# %%
ls
# Out:
# Untitled.ipynb    js/               social-power-nba/
# app.py            python/           templates/

# %%
cd social-power-nba
# Out:
# /Users/danielkline/Desktop/datascience/Projects/project3/social-power-nba

# %%
ls
# Out:
# nba_2016_2017_100.csv*
# nba_2017_att_val.csv*
# nba_2017_att_val_elo.csv*
# nba_2017_att_val_elo_with_cluster.csv*
# nba_2017_attendance.csv*
# nba_2017_br.csv*
# nba_2017_elo.csv*
# nba_2017_endorsements.csv*
# nba_2017_nba_players_with_salary.csv*
# nba_2017_pie.csv*
# nba_2017_player_wikipedia.csv*
# nba_2017_players_stats_combined.csv*
# nba_2017_players_with_salary_wiki_twitter.csv*
# nba_2017_real_plus_minus.csv*
# nba_2017_salary.csv*
# nba_2017_team_valuations.csv*
# nba_2017_twitter_players.csv*

# %%
choosen_csv = 'nba_2017_pie.csv'
ctv = 0
with open(choosen_csv,'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    for line in csv_reader:
        if ctv == 0:
            csv_col_num = len(line)
            arr = []
            for x in list(range(0,csv_col_num)):
                arr.append([])
                ctv = 1
        
        for x in list(range(0,csv_col_num)):
            arr[x].append(line[x])
                
        
        
df = pd.DataFrame(arr)
new_header = df.iloc[0] 
df = df[1:] 
df.columns = new_header

# %%
pd.read_csv(choosen_csv)
# Out:
#                 PLAYER TEAM  AGE  GP   W   L   MIN  OFFRTG  DEFRTG  NETRTG  \
# 0    Russell Westbrook  OKC   28  81  46  35  34.6   107.9   104.6     3.3
# 1     Boban Marjanovic  DET   28  35  16  19   8.4   104.3   102.4     1.9
# 2    Demetrius Jackson  BOS   22   5   1   4   3.4   124.2   117.8     6.3
# 3        Anthony Davis  NOP   24  75  31  44  36.1   104.2   102.5     1.7
# 4         James Harden  HOU   27  81  54  27  36.4   113.6   107.3     6.3
# ..                 ...  ...  ...  ..  ..  ..   ...     ...     ...     ...
# 481     Elijah Millsap  PHX   29   2   1   1  11.6    91.2    93.0    -1.8
# 482          Gary Neal  ATL   32   2   1   1   9.2    80.6    98.6   -18.0
# 483    Patricio Garino  ORL   24   5   2   3   8.6    93.3   114.4   -21.1
# 484      Larry Sanders  CLE   28   5   2   3   2.5    93.4   100.6    -7.2
# 485         Ben Bentil  DAL   22   3   2   1   3.3    91.5   135.5   -44.0
#
#      ...  AST RATIO  OREB%  DREB%  REB%  TO RATIO  EFG%   TS%  USG%    PACE  \
# 0    ...       23.4    5.3   27.9  16.7      12.2  47.6  55.4  40.8  102.31
# 1    ...        5.1   16.6   31.3  23.9       5.7  54.5  60.6  24.8   97.20
# 2    ...       31.1    9.1   11.8  10.3       0.0  87.5  75.3  17.2   87.46
# 3    ...        7.3    6.7   26.9  17.0       8.4  51.8  58.0  32.6  100.19
# 4    ...       27.6    3.5   21.2  12.3      14.1  52.5  61.3  34.1  102.98
# ..   ...        ...    ...    ...   ...       ...   ...   ...   ...     ...
# 481  ...        9.2   12.5   15.0  13.6      18.4  14.3  19.0  19.9   94.58
# 482  ...       10.2    0.0    7.7   2.7       0.0   0.0  22.8  20.1   98.18
# 483  ...        0.0    2.5   13.3   8.2      30.0   0.0   0.0  10.3   95.65
# 484  ...        0.0   37.5   11.1  23.5      29.1  25.0  41.0  22.4   99.45
# 485  ...        0.0    0.0   25.0  12.5      25.0   0.0   0.0  18.4  106.15
#
#       PIE
# 0    23.0
# 1    19.6
# 2    19.4
# 3    19.2
# 4    19.0
# ..    ...
# 481  -3.6
# 482  -4.4
# 483  -4.9
# 484  -5.6
# 485  -6.1
#
# [486 rows x 22 columns]

# %%
col_list = []
for col in pd.read_csv(choosen_csv).columns:
    col_list.append(col)
col_list[0]
# Out:
# 'PLAYER'

# %%
for x in col_list:
    print(x)
    
col_list[0]
# Out:
# PLAYER
# TEAM
# AGE
# GP
# W
# L
# MIN
# OFFRTG
# DEFRTG
# NETRTG
# AST%
# AST/TO
# AST RATIO
# OREB%
# DREB%
# REB%
# TO RATIO
# EFG%
# TS%
# USG%
# PACE
# PIE
# 'PLAYER'

# %%
arr = []
for x in list(range(0,4)):
                col_ = 2
                arr.append(col_+x)
# Out:
#   File "<ipython-input-33-6fb691690db2>", line 3
#     "col_"+x = 2
#     ^
# SyntaxError: can't assign to operator

# %%
col_list = []
for col in pd.read_csv(choosen_csv).columns:
    col_list.append(col)

plt.bar(pd.read_csv(choosen_csv)[col_list[0]].head(10), pd.read_csv(choosen_csv).AGE.head(10), color='r', alpha=0.5, align="center")
# Out:
# <BarContainer object of 10 artists>

# %%
df.head()
# Out:
#        0                  1                 2                  3    \
# 0  ﻿PLAYER  Russell Westbrook  Boban Marjanovic  Demetrius Jackson
# 1     TEAM                OKC               DET                BOS
# 2      AGE                 28                28                 22
# 3       GP                 81                35                  5
# 4        W                 46                16                  1
#
#              4             5             6             7           8    \
# 0  Anthony Davis  James Harden  Kevin Durant  LeBron James  Chris Paul
# 1            NOP           HOU           GSW           CLE         LAC
# 2             24            27            28            32          32
# 3             75            81            62            74          61
# 4             31            54            51            51          43
#
#                 9    ...              477            478            479  \
# 0  DeMarcus Cousins  ...  Lamar Patterson  Isaiah Taylor  Diamond Stone
# 1               NOP  ...              ATL            HOU            LAC
# 2                26  ...               25             22             20
# 3                72  ...                5              4              7
# 4                30  ...                1              3              6
#
#           480              481             482        483              484  \
# 0  Mike Tobey  Michael Gbinije  Elijah Millsap  Gary Neal  Patricio Garino
# 1         CHA              DET             PHX        ATL              ORL
# 2          22               25              29         32               24
# 3           2                9               2          2                5
# 4           0                7               1          1                2
#
#              485         486
# 0  Larry Sanders  Ben Bentil
# 1            CLE         DAL
# 2             28          22
# 3              5           3
# 4              2           2
#
# [5 rows x 487 columns]

# %%
df_return = df.loc[df == "James Harden", :]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b234c16aa1ee> in <module>
# ----> 1 df_return = df.loc[df == "James Harden", :]
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     820                 continue
#     821
# --> 822             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     823
#     824         return retval
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1835
#    1836                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1837                     raise ValueError("Cannot index with multidimensional key")
#    1838
#    1839                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
choosen_csv = "nba_2017_players_stats_combined.csv"
pd.read_csv(choosen_csv)
# Out:
#      Unnamed: 0   Rk             PLAYER POSITION  AGE    MP    FG   FGA  \
# 0             0    1  Russell Westbrook       PG   28  34.6  10.2  24.0
# 1             1    2       James Harden       PG   27  36.4   8.3  18.9
# 2             2    3      Isaiah Thomas       PG   27  33.8   9.0  19.4
# 3             3    4      Anthony Davis        C   23  36.1  10.3  20.3
# 4             4    5      DeMar DeRozan       SG   27  35.4   9.7  20.9
# ..          ...  ...                ...      ...  ...   ...   ...   ...
# 441         441  480    Michael Gbinije       SG   24   3.6   0.1   1.1
# 442         442  481     John Lucas III       PG   34   2.2   0.2   0.8
# 443         443  482     Aaron Harrison       SG   22   3.4   0.0   0.8
# 444         444  483         Ben Bentil       PF   21   3.3   0.0   1.0
# 445         445  484    Patricio Garino       SG   23   8.6   0.0   1.4
#
#        FG%   3P  ...  TEAM  GP   MPG  ORPM  DRPM   RPM  WINS_RPM   PIE  \
# 0    0.425  2.5  ...   OKC  81  34.6  6.74 -0.47  6.27     17.34  23.0
# 1    0.440  3.2  ...   HOU  81  36.4  6.38 -1.57  4.81     15.54  19.0
# 2    0.463  3.2  ...   BOS  76  33.8  5.72 -3.89  1.83      8.19  16.1
# 3    0.505  0.5  ...    NO  75  36.1  0.45  3.90  4.35     12.81  19.2
# 4    0.467  0.4  ...   TOR  74  35.4  2.21 -2.04  0.17      5.46  15.5
# ..     ...  ...  ...   ...  ..   ...   ...   ...   ...       ...   ...
# 441  0.100  0.0  ...   DET   9   3.6 -2.17 -0.17 -2.34      0.02  -2.7
# 442  0.250  0.0  ...   MIN   5   2.2 -1.30 -0.61 -1.91      0.01   7.3
# 443  0.000  0.0  ...   CHA   5   3.4 -1.42 -0.32 -1.74      0.01   0.0
# 444  0.000  0.0  ...   DAL   3   3.3 -1.95  0.65 -1.30      0.01  -6.1
# 445  0.000  0.0  ...   ORL   5   8.6 -2.61 -0.40 -3.01      0.00  -4.9
#
#        PACE   W
# 0    102.31  46
# 1    102.98  54
# 2     99.84  51
# 3    100.19  31
# 4     97.69  47
# ..      ...  ..
# 441   91.34   7
# 442   94.47   3
# 443   92.43   2
# 444  106.15   2
# 445   95.65   2
#
# [446 rows x 38 columns]

# %%
ls
# Out:
# nba_2016_2017_100.csv*
# nba_2017_att_val.csv*
# nba_2017_att_val_elo.csv*
# nba_2017_att_val_elo_with_cluster.csv*
# nba_2017_attendance.csv*
# nba_2017_br.csv*
# nba_2017_elo.csv*
# nba_2017_endorsements.csv*
# nba_2017_nba_players_with_salary.csv*
# nba_2017_pie.csv*
# nba_2017_player_wikipedia.csv*
# nba_2017_players_stats_combined.csv*
# nba_2017_players_with_salary_wiki_twitter.csv*
# nba_2017_real_plus_minus.csv*
# nba_2017_salary.csv*
# nba_2017_team_valuations.csv*
# nba_2017_twitter_players.csv*

# %%
choosen_csv = "nba_2016_2017_100.csv"
pd.read_csv(choosen_csv).head()
# Out:
#    PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  AGE  GP   W  \
# 0     201566  Russell Westbrook  1610612760               OKC   28  81  46
# 1    1626246   Boban Marjanovic  1610612765               DET   28  35  16
# 2    1627743  Demetrius Jackson  1610612738               BOS   22   5   1
# 3     203076      Anthony Davis  1610612740               NOP   24  75  31
# 4     201935       James Harden  1610612745               HOU   27  81  54
#
#     L  W_PCT   MIN  ...  FGA_PG_RANK  FG_PCT_RANK  CFID  \
# 0  35  0.568  34.6  ...            1          293     5
# 1  19  0.457   8.4  ...          356           47     5
# 2   4  0.200   3.4  ...          480            3     5
# 3  44  0.413  36.1  ...            3           95     5
# 4  27  0.667  36.4  ...            9          253     5
#
#                  CFPARAMS            WIKIPEDIA_HANDLE  TWITTER_HANDLE  \
# 0   2,015,661,610,612,760           Russell_Westbrook      russwest44
# 1  16,262,461,610,612,700            Boban_Marjanovi_               0
# 2  16,277,431,610,612,700           Demetrius_Jackson         d_jay11
# 3   2,030,761,610,612,740  Anthony_Davis_(basketball)      antdavis23
# 4   2,019,351,610,612,740                James_Harden       jharden13
#
#    SALARY_MILLIONS   PTS  ACTIVE_TWITTER_LAST_YEAR  \
# 0            26.54  31.6                         1
# 1             7.00   5.5                         0
# 2             1.45   2.0                         1
# 3            22.12  28.0                         1
# 4            26.50  29.1                         1
#
#    TWITTER_FOLLOWER_COUNT_MILLIONS
# 0                            4.500
# 1                            0.000
# 2                            0.049
# 3                            1.220
# 4                            4.470
#
# [5 rows x 63 columns]

# %%
choosen_csv = "nba_2017_att_val.csv"
pd.read_csv(choosen_csv).head()
# Out:
#    Unnamed: 0              TEAM  GMS   TOTAL    AVG    PCT  VALUE_MILLIONS
# 0           0     Chicago Bulls   41  888882  21680  103.6            2500
# 1           1  Dallas Mavericks   41  811366  19789  103.1            1450
# 2           2  Sacramento Kings   41  721928  17608  100.6            1075
# 3           3        Miami Heat   41  805400  19643  100.2            1350
# 4           4   Toronto Raptors   41  813050  19830  100.2            1125

# %%
choosen_csv = "nba_2017_att_val_elo.csv"
pd.read_csv(choosen_csv).head()
# Out:
#    Unnamed: 0              TEAM  GMS   TOTAL    AVG    PCT  VALUE_MILLIONS  \
# 0           0     Chicago Bulls   41  888882  21680  103.6          2500.0
# 1           1  Dallas Mavericks   41  811366  19789  103.1          1450.0
# 2           2  Sacramento Kings   41  721928  17608  100.6          1075.0
# 3           3        Miami Heat   41  805400  19643  100.2          1350.0
# 4           4   Toronto Raptors   41  813050  19830  100.2          1125.0
#
#     ELO  CONF
# 0  1519  East
# 1  1420  West
# 2  1393  West
# 3  1569  East
# 4  1600  East

# %%
choosen_csv = "nba_2017_att_val_elo_with_cluster.csv"
pd.read_csv(choosen_csv).head()
# Out:
#    Unnamed: 0              TEAM  GMS   TOTAL    AVG    PCT  VALUE_MILLIONS  \
# 0           0     Chicago Bulls   41  888882  21680  103.6          2500.0
# 1           1  Dallas Mavericks   41  811366  19789  103.1          1450.0
# 2           2  Sacramento Kings   41  721928  17608  100.6          1075.0
# 3           3        Miami Heat   41  805400  19643  100.2          1350.0
# 4           4   Toronto Raptors   41  813050  19830  100.2          1125.0
#
#     ELO  CONF  cluster
# 0  1519  East        1
# 1  1420  West        1
# 2  1393  West        0
# 3  1569  East        1
# 4  1600  East        1

# %%
choosen_csv = "nba_2017_attendance.csv"
pd.read_csv(choosen_csv).head()
# Out:
#                TEAM  GMS   TOTAL    AVG    PCT
# 0     Chicago Bulls   41  888882  21680  103.6
# 1  Dallas Mavericks   41  811366  19789  103.1
# 2  Sacramento Kings   41  721928  17608  100.6
# 3        Miami Heat   41  805400  19643  100.2
# 4   Toronto Raptors   41  813050  19830  100.2

# %%
choosen_csv = "nba_2017_br.csv"
pd.read_csv(choosen_csv).head()
# Out:
#    Rk             Player Pos  Age   Tm   G  GS    MP    FG   FGA  ...    FT%  \
# 0   1  Russell Westbrook  PG   28  OKC  81  81  34.6  10.2  24.0  ...  0.845
# 1   2       James Harden  PG   27  HOU  81  81  36.4   8.3  18.9  ...  0.847
# 2   3      Isaiah Thomas  PG   27  BOS  76  76  33.8   9.0  19.4  ...  0.909
# 3   4      Anthony Davis   C   23  NOP  75  75  36.1  10.3  20.3  ...  0.802
# 4   5      DeMar DeRozan  SG   27  TOR  74  74  35.4   9.7  20.9  ...  0.842
#
#    ORB  DRB   TRB   AST  STL  BLK  TOV   PF  PS/G
# 0  1.7  9.0  10.7  10.4  1.6  0.4  5.4  2.3  31.6
# 1  1.2  7.0   8.1  11.2  1.5  0.5  5.7  2.7  29.1
# 2  0.6  2.1   2.7   5.9  0.9  0.2  2.8  2.2  28.9
# 3  2.3  9.5  11.8   2.1  1.3  2.2  2.4  2.2  28.0
# 4  0.9  4.3   5.2   3.9  1.1  0.2  2.4  1.8  27.3
#
# [5 rows x 30 columns]

# %%
choosen_csv = "nba_2017_elo.csv"
pd.read_csv(choosen_csv).head()
# Out:
#     ELO                   TEAM  CONF
# 0  1770  Golden State Warriors  West
# 1  1661      San Antonio Spurs  West
# 2  1636   Los Angeles Clippers  West
# 3  1617              Utah Jazz  West
# 4  1602        Houston Rockets  West

# %%
choosen_csv = "nba_2017_endorsements.csv"
pd.read_csv(choosen_csv).head()
# Out:
#                 NAME                   TEAM           SALARY     ENDORSEMENT
# 0       LeBron James    Cleveland Cavaliers   $30,963,450.00  $55,000,000.00
# 1       Kevin Durant  Golden State Warriors   $26,500,000.00  $36,000,000.00
# 2      Stephen Curry  Golden State Warriors  $12,112,359.00   $35,000,000.00
# 3       James Harden        Houston Rockets   $26,500,000.00  $20,000,000.00
# 4  Russell Westbrook  Oklahoma City Thunder   $26,500,000.00  $15,000,000.00

# %%
choosen_csv = "nba_2017_endorsements.csv"
pd.read_csv(choosen_csv).head()
# Out:
#                 NAME                   TEAM           SALARY     ENDORSEMENT
# 0       LeBron James    Cleveland Cavaliers   $30,963,450.00  $55,000,000.00
# 1       Kevin Durant  Golden State Warriors   $26,500,000.00  $36,000,000.00
# 2      Stephen Curry  Golden State Warriors  $12,112,359.00   $35,000,000.00
# 3       James Harden        Houston Rockets   $26,500,000.00  $20,000,000.00
# 4  Russell Westbrook  Oklahoma City Thunder   $26,500,000.00  $15,000,000.00

# %%
choosen_csv = "nba_2017_nba_players_with_salary.csv"
pd.read_csv(choosen_csv).head(50)
# Out:
#     Unnamed: 0  Rk                 PLAYER POSITION  AGE    MP    FG   FGA  \
# 0            0   1      Russell Westbrook       PG   28  34.6  10.2  24.0
# 1            1   2           James Harden       PG   27  36.4   8.3  18.9
# 2            2   3          Isaiah Thomas       PG   27  33.8   9.0  19.4
# 3            3   4          Anthony Davis        C   23  36.1  10.3  20.3
# 4            4   6       DeMarcus Cousins        C   26  34.2   9.0  19.9
# 5            5   7         Damian Lillard       PG   26  35.9   8.8  19.8
# 37  0.476  2.0  ...  61  31.5  5.16  2.76  7.92     13.48  18.2   98.19  43
# 38  0.450  1.7  ...  66  32.8 -0.31  1.90  1.59      6.54  10.6   99.15  26
# 39  0.471  0.2  ...  64  32.5  0.11 -2.36 -2.25      1.17  11.2   99.19  26
# 40  0.451  1.3  ...  79  31.5  0.31 -2.76 -2.45      1.07  11.7  100.32  42
# 41  0.477  0.3  ...  72  32.4 -0.09  1.05  0.96      5.79  12.2   94.47  52
# 42  0.439  1.9  ...  68  32.9  0.07 -1.17 -1.10      2.89   8.5   99.60  23
# 43  0.477  1.9  ...  49  31.5  2.64  1.11  3.75      6.28  12.8   92.90  33
# 44  0.578  0.6  ...  73  27.9  4.44  2.29  6.73     13.18  16.7  100.76  37
# 45  0.463  2.0  ...  55  33.4 -0.44 -1.72 -2.16      1.13   9.9   99.23  34
# 46  0.406  3.3  ...  75  31.0  1.51 -0.48  1.03      6.36   8.2  103.07  50
# 47  0.481  1.3  ...  82  31.3  1.19 -0.25  0.94      6.55  11.3   97.41  37
# 48  0.442  1.9  ...  67  33.2  0.10  1.56  1.66      6.88   9.5  101.10  39
# 49  0.424  1.8  ...  46  30.1  0.12 -0.07  0.05      2.80  10.0   98.03  27
#
#     SALARY_MILLIONS
# 0             26.50
# 1             26.50
# 2              6.59
# 3             22.12
# 4             16.96
# 5             24.33
# 6             30.96
# 7             17.64
# 8             12.11
# 9             17.64
# 10            26.50
# 11             5.96
# 12            17.55
# 13            18.31
# 14             6.01
# 15            12.00
# 16            22.12
# 17            16.96
# 18             3.00
# 19            24.56
# 20            16.66
# 21             2.22
# 22            16.07
# 23            20.14
# 24            14.00
# 25            26.54
# 26            21.17
# 27            15.89
# 28             4.83
# 29             5.37
# 30            21.17
# 31            21.17
# 32             2.24
# 33            13.33
# 34            23.20
# 35            15.05
# 36            20.07
# 37            22.87
# 38             4.32
# 39            21.32
# 40             2.71
# 41            20.58
# 42            17.00
# 43             8.00
# 44             1.36
# 45             8.27
# 46            12.39
# 47            17.20
# 48             6.55
# 49             2.90
#
# [50 rows x 39 columns]

# %%
choosen_csv = ""
pd.read_csv(choosen_csv)

# %%
choosen_csv = ""
pd.read_csv(choosen_csv)

# %%
choosen_csv = ""
pd.read_csv(choosen_csv)

# %%
conda activate pythondata
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
player_name = "kobe bryant"
first_name = player_name.split(" ")[0]
last_name = player_name.split(" ")[1]
image_url = "https://en.wikipedia.org/wiki/"+first_name+"_"+last_name
request = requests.get(image_url)
soup4 = BeautifulSoup(request.text, 'html.parser')
result = soup4.find_all(attrs={'class','infobox vcard'})

url_image_scraped = "https://" + result[0].table.img.get("src").replace("//","",1)

# %%
from IPython.display import Image
Image(url_image_scraped)

# %%
soup4.find_all(attrs={'class','image'})[0].img##.find_all(attrs={"img","src"})
# Out:
# <img alt="Kobe Bryant warming up.jpg" data-file-height="2476" data-file-width="1410" decoding="async" height="386" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Kobe_Bryant_warming_up.jpg/220px-Kobe_Bryant_warming_up.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Kobe_Bryant_warming_up.jpg/330px-Kobe_Bryant_warming_up.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/05/Kobe_Bryant_warming_up.jpg/440px-Kobe_Bryant_warming_up.jpg 2x" width="220"/>
