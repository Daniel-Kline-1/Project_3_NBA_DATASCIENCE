# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from IPython.display import Image
from pprint import pprint
import os

# %%
player_name = "lebron james"
first_name = player_name.split(" ")[0]
last_name = player_name.split(" ")[1]
image_url = "https://en.wikipedia.org/wiki/"+first_name+"_"+last_name
request = requests.get(image_url)
soup4 = BeautifulSoup(request.text, 'html.parser')
result = soup4.find_all(attrs={'class','infobox vcard'})

url_image_scraped = "https://" + result[0].img.get("src").replace("//","",1)
Image(url_image_scraped)

# %%
soup4
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Michael Jordan - Wikipedia</title>
# ...

# %%
result[0].img.get("src")
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/a/ae/Michael_Jordan_in_2014.jpg/220px-Michael_Jordan_in_2014.jpg'

# %%
from flask import jsonify

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-aa542bb1c747> in <module>
# ----> 1 jsonify([{"hello":"world"}])
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/flask/json/__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/werkzeug/local.py in __getattr__(self, name)
#     346         if name == "__members__":
#     347             return dir(self._get_current_object())
# --> 348         return getattr(self._get_current_object(), name)
#     349
#     350     def __setitem__(self, key, value):
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
import os

import pandas as pd
import numpy as np
import numpy as np
import requests
#import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import pandas as pd

import csv
from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy
#import python_project.python_run 
from sqlalchemy import create_engine
import json
import os
from pprint import pprint

# %%
df
# Out:
#      Unnamed: 0   Rk             PLAYER POSITION  AGE    MP    FG   FGA  \
# 0             0    1  Russell Westbrook       PG   28  34.6  10.2  24.0
# 1             1    2       James Harden       PG   27  36.4   8.3  18.9
# 2             2    4      Anthony Davis        C   23  36.1  10.3  20.3
# 3             3    6   DeMarcus Cousins        C   26  34.2   9.0  19.9
# 4             4    7     Damian Lillard       PG   26  35.9   8.8  19.8
# ..          ...  ...                ...      ...  ...   ...   ...   ...
# 234         234  455      Nick Collison       PF   36   6.4   0.7   1.2
# 235         235  457      Bruno Caboclo       SF   21   4.4   0.7   1.8
# 236         236  459         Ryan Kelly       PF   25   6.9   0.5   1.8
# 237         237  460      Jordan Mickey       PF   22   5.6   0.6   1.4
# 238         238  475         Alonzo Gee       SF   29   6.8   0.2   1.1
#
#        FGp  threeP  ...  DRPM   RPM  WINS_RPM   PIE    PACE   W  \
# ...

# %%
#df.to_sql('NBA', con=engine)
engine.execute("SELECT * FROM NBA").fetchall()
# Out:
# [(0, 0, 1, 'Russell Westbrook', 'PG', 28, 34.6, 10.2, 24.0, 0.425, 2.5, 7.2, 0.343, 7.7, 16.8, 0.459, 0.476, 8.8, 10.4, 0.845, 1.7, 9.0, 10.7, 10.4, 1.6, 0.4, 5.4, 2.3, 31.6, 'OKC', 81, 34.6, 6.74, -0.47, 6.27, 17.34, 23.0, 102.31, 46, 26.5, 4279.0, 2130.5, 559.0),
#  (1, 1, 2, 'James Harden', 'PG', 27, 36.4, 8.3, 18.9, 0.44, 3.2, 9.3, 0.34700000000000003, 5.1, 9.6, 0.53, 0.525, 9.2, 10.9, 0.847, 1.2, 7.0, 8.1, 11.2, 1.5, 0.5, 5.7, 2.7, 29.1, 'HOU', 81, 36.4, 6.38, -1.57, 4.81, 15.54, 19.0, 102.98, 54, 26.5, 3279.0, 969.0, 321.5),
#  (2, 2, 4, 'Anthony Davis', 'C', 23, 36.1, 10.3, 20.3, 0.505, 0.5, 1.8, 0.299, 9.7, 18.6, 0.524, 0.518, 6.9, 8.6, 0.802, 2.3, 9.5, 11.8, 2.1, 1.3, 2.2, 2.4, 2.2, 28.0, 'NO', 75, 36.1, 0.45, 3.9, 4.35, 12.81, 19.2, 100.19, 31, 22.12, 82.5, 368.0, 104.0),
# ...

# %%
df.to_json()[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35a20425a4e5> in <module>
# ----> 1 df.to_json()[0]
#
# NameError: name 'df' is not defined

# %%
filepath = os.path.join("static", "social-power-nba", "nbaJSON.json")
with open(filepath) as jsonfile:
    json_data = json.load(jsonfile)

# %%
len(json_data)
# Out:
# 239

# %%
wordFreqDic = {
    "Hello": 56,
    "at" : 23 ,
    "test" : 43,
    "this" : 43
    }

# %%
dictt
# Out:
# {'before': 23}

# %%
dictt.update( {'before' : 23} )

# %%
wordFreqDic['Hello']
# Out:
# 56

# %%
ls
# Out:
# README.md  Test/      project3/

# %%
cd project3/
# Out:
# /Users/danielkline/Desktop/datascience/Projects/Project_3_NBA_DATASCIENCE/project3

# %%
 filepath = os.path.join("static", "social-power-nba", "nbaJSON.json")
with open(filepath) as jsonfile:
    json_data = json.load(jsonfile)

# %%
for row in list(range(len(json_data))):
    print(json_data[row]['player'])
# Out:
# Russell Westbrook
# James Harden
# Anthony Davis
# DeMarcus Cousins
# Damian Lillard
# LeBron James
# Kawhi Leonard
# Stephen Curry
# Kyrie Irving
# Kevin Durant
# Karl-Anthony Towns
# Jimmy Butler
# Paul George
# Andrew Wiggins
# Kemba Walker
# Bradley Beal
# John Wall
# Carmelo Anthony
# Klay Thompson
# Devin Booker
# Gordon Hayward
# Blake Griffin
# Eric Bledsoe
# Mike Conley
# Goran Dragic
# Joel Embiid
# Jabari Parker
# Marc Gasol
# Kevin Love
# Zach LaVine
# Dwyane Wade
# Danilo Gallinari
# Paul Millsap
# Chris Paul
# Kristaps Porzingis
# Derrick Rose
# Dennis Schroder
# LaMarcus Aldridge
# Evan Fournier
# George Hill
# Nikola Jokic
# Eric Gordon
# Tobias Harris
# Victor Oladipo
# Dion Waiters
# Wilson Chandler
# D'Angelo Russell
# Jrue Holiday
# Jeff Teague
# Nicolas Batum
# Gary Harris
# Jordan Clarkson
# Khris Middleton
# Nikola Vucevic
# Jeremy Lin
# Myles Turner
# Enes Kanter
# Dirk Nowitzki
# Zach Randolph
# Rudy Gobert
# Al Horford
# Marcus Morris
# Markieff Morris
# ...

# %%
 filepath = os.path.join("static", "social-power-nba", "nbaJSON.json")
with open(filepath) as jsonfile:
    json_data = json.load(jsonfile)

# %%
for x in list(range(0,len(json_data))):
    if json_data[x]['player'] == "Greg Monroe":
        y = json_data[x]
        print(y)
# Out:
# {'fg': 4.8, 'mp': 22.5, 'orpm': 1.08, 'salary_millions': 17.15, 'points': 11.7, 'drpm': 0.47, 'stl': 1.1, 'orb': 2.1, 'twitter_favorite_count': '9.0', 'ast': 2.3, 'gp': 81, 'fta': 3.0, 'team': 'MIL', 'twitter_retweet_count': '7.0', 'trb': 6.6, 'f_gp': 0.5329999999999999, 'pace': 96.98, 'three_p': 0.0, 'pageviews': 271.0, 'drb': 4.5, 'two_pa': 8.9, 'age': 26, 'two_pp': 0.536, 'e_f_gp': 0.5329999999999999, 'blk': 0.5, 'three_pa': 0.0, 'pf': 2.1, 'ft': 2.2, 'field_0': 79, 'tov': 1.7, 'wins_rpm': 5.34, 'mpg': 22.5, 'rk': 112, 'two_p': 4.8, 'fga': 9.0, 'position': 'C', 'f_tp': '0.741', 'pie': 13.9, 'w': 42, 'rpm': 1.55, 'player': 'Greg Monroe', 'three_pp': '0.0'}

# %%
json_data
# Out:
# [{'fg': 10.2,
#   'mp': 34.6,
#   'orpm': 6.74,
#   'salary_millions': 26.5,
#   'points': 31.6,
#   'drpm': -0.47,
#   'stl': 1.6,
#   'orb': 1.7,
#   'twitter_favorite_count': '2130.5',
#   'ast': 10.4,
#   'gp': 81,
#   'fta': 10.4,
#   'team': 'OKC',
#   'twitter_retweet_count': '559.0',
#   'trb': 10.7,
#   'f_gp': 0.425,
#   'pace': 102.31,
#   'three_p': 2.5,
#   'pageviews': 4279.0,
#   'drb': 9.0,
#   'two_pa': 16.8,
#   'age': 28,
#   'two_pp': 0.45899999999999996,
#   'e_f_gp': 0.47600000000000003,
#   'blk': 0.4,
#   'three_pa': 7.2,
#   'pf': 2.3,
#   'ft': 8.8,
#   'field_0': 0,
#   'tov': 5.4,
#   'wins_rpm': 17.34,
#   'mpg': 34.6,
#   'rk': 1,
#   'two_p': 7.7,
#   'fga': 24.0,
#   'position': 'PG',
#   'f_tp': '0.845',
#   'pie': 23.0,
#   'w': 46,
#   'rpm': 6.27,
#   'player': 'Russell Westbrook',
#   'three_pp': '0.34299999999999997'},
#  {'fg': 8.3,
#   'mp': 36.4,
#   'orpm': 6.38,
#   'salary_millions': 26.5,
#   'points': 29.1,
#   'drpm': -1.57,
# ...
